# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
x=np.array(Image.open('cow.jpg'))
plt.imshow(x,plt.cm.gray)
plt.show()

# %%
[p,q,t]=x.shape
x=x/255.0

# %%
choose=np.zeros([p,q])
choose[125:130,100:200]=1.0
plt.imshow(choose,plt.cm.gray)

# %%
alpha=1
beta=0.5
y=choose
myvalue=np.zeros([p,q])
for l in range(1,p-1):
    for k in range(1,q-1):
        Energy1=alpha*(x[l,k]-x[125:130,100:200])**2+beta*(abs(y[l,k]-y[l+1,k])+abs(y[l,k]-y[l-1,k])+abs(y[l,k]-y[l,k-1])+abs(y[l,k]-y[l,k+1]))

        if np.sum(Energy1)<60:
            myvalue[l,k]=1
        else:
            myvalue[l,k]=0

# %%
np.sum(Energy1),np.sum(np.sum(np.sum(Energy1,axis=2),axis=1))
# Out:
# (90.039430988081506, 90.03943098808152)

# %%
plt.figure(figsize=(15,15))
plt.imshow(myvalue,plt.cm.gray)
plt.show()
